# %%
import torch as tp
import pandas as pd 
from sklearn.preprocessing import StandardScaler
from torch.utils.data import Dataset,DataLoader
from sklearn.model_selection import train_test_split as tts

# %%
data=pd.read_csv('Syntheticdata.csv')
X=data.iloc[:,:-1]
y=data.iloc[:,-1]

# %%
X_np=X.to_numpy()
y_np=y.to_numpy()

# %%
X_tensor=tp.tensor(X_np,dtype=tp.float64)
y_tensor=tp.tensor(y_np,dtype=tp.float64)

# %%
class CustomDataset(Dataset):
    def __init__(self,features,labels):
        self.features=features
        self.labels=labels

    def __len__(self):
        return self.features.shape[0]
    
    def __getitem__(self, index):
        return self.features[index],self.labels[index]

# %%
dataset=CustomDataset(X_tensor,y_tensor)
dataloader=DataLoader(dataset,batch_size=2,shuffle=True)
for batch_features,batch_label in dataloader:
    print(batch_features)
    print(batch_label)
    print('-'*50)
# Out:
# tensor([[-0.2346, -2.3053, -0.4225],
#         [ 2.1905,  1.7442,  1.1241]], dtype=torch.float64)
# tensor([0., 1.], dtype=torch.float64)
# --------------------------------------------------
# tensor([[ 0.1746, -1.4525,  0.2540],
#         [ 1.8862, -0.5516,  1.7058]], dtype=torch.float64)
# tensor([1., 1.], dtype=torch.float64)
# --------------------------------------------------
# tensor([[-0.1924, -0.4627, -2.4459],
#         [-1.4635,  0.1497, -1.3996]], dtype=torch.float64)
# tensor([0., 0.], dtype=torch.float64)
# --------------------------------------------------
# tensor([[-1.4154, -1.8819, -0.3315],
#         [ 0.2576, -0.5479,  1.7281]], dtype=torch.float64)
# tensor([0., 1.], dtype=torch.float64)
# --------------------------------------------------
# tensor([[ 0.0051, -0.4598, -2.0992],
#         [ 0.0686, -0.5047,  0.7861]], dtype=torch.float64)
# tensor([0., 1.], dtype=torch.float64)
# --------------------------------------------------
# tensor([[-0.4206, -1.4870, -1.2665],
#         [-0.3921, -1.1489, -1.0023]], dtype=torch.float64)
# tensor([0., 0.], dtype=torch.float64)
# --------------------------------------------------
# tensor([[-0.3277, -0.7450, -0.5463],
#         [ 0.7519,  2.1345,  0.3272]], dtype=torch.float64)
# tensor([0., 0.], dtype=torch.float64)
# --------------------------------------------------
# tensor([[-0.9094,  1.5450, -0.0711],
#         [ 0.0997,  2.2067,  1.1456]], dtype=torch.float64)
# tensor([0., 1.], dtype=torch.float64)
# --------------------------------------------------
# tensor([[-0.5035,  0.0542,  2.7069],
#         [ 1.4028,  0.5632,  1.2858]], dtype=torch.float64)
# tensor([1., 1.], dtype=torch.float64)
# --------------------------------------------------
# tensor([[-0.0347,  0.8249, -2.0980],
#         [-1.5507,  0.8181,  0.9219]], dtype=torch.float64)
# tensor([0., 1.], dtype=torch.float64)
# --------------------------------------------------
# tensor([[-0.1613, -0.7514,  1.3854],
#         [ 0.2961, -1.4799, -0.4873]], dtype=torch.float64)
# tensor([1., 0.], dtype=torch.float64)
# --------------------------------------------------
# tensor([[-0.8023, -0.4375,  1.9082],
#         [ 0.3015,  0.8862, -0.4985]], dtype=torch.float64)
# tensor([1., 0.], dtype=torch.float64)
# --------------------------------------------------
# tensor([[-1.1687,  1.1758, -1.0864],
#         [-0.7021, -0.5703, -1.3197]], dtype=torch.float64)
# tensor([0., 0.], dtype=torch.float64)
# --------------------------------------------------
# tensor([[ 0.0602,  1.6804, -0.4176],
#         [-1.4019, -0.6111,  1.5994]], dtype=torch.float64)
# tensor([0., 0.], dtype=torch.float64)
# --------------------------------------------------
# tensor([[ 1.1428,  0.5815, -0.9627],
#         [-0.9905,  0.7131,  0.7225]], dtype=torch.float64)
# tensor([0., 1.], dtype=torch.float64)
# --------------------------------------------------
# tensor([[-0.0744, -0.9328,  1.1313],
#         [ 2.4632,  0.8203, -1.2950]], dtype=torch.float64)
# tensor([1., 0.], dtype=torch.float64)
# --------------------------------------------------
# tensor([[-1.9188, -0.2893,  2.1511],
#         [-0.0265, -0.3624,  1.9903]], dtype=torch.float64)
# tensor([1., 1.], dtype=torch.float64)
# --------------------------------------------------
# tensor([[ 0.5869,  2.5583,  0.5974],
#         [-0.5663,  2.4270,  0.8945]], dtype=torch.float64)
# tensor([1., 1.], dtype=torch.float64)
# --------------------------------------------------
# tensor([[-0.3427, -1.7000, -0.0870],
#         [ 0.4041, -0.5337,  1.7192]], dtype=torch.float64)
# tensor([1., 1.], dtype=torch.float64)
# --------------------------------------------------
# tensor([[ 0.2611, -1.2943, -1.0057],
#         [ 0.7910,  0.1963, -1.7469]], dtype=torch.float64)
# tensor([0., 0.], dtype=torch.float64)
# --------------------------------------------------
